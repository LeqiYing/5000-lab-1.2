# %% [markdown]
# ---
# mode: "revealjs"
# theme: "white"
# transition: "slide"
# verticalSeparator: "^"
# horizontalSeparator: "---"
# ---

# %% [markdown]
# ## Slide 1
#
# book{wickham2023r,
#   title={R for Data Science},
#   author={Wickham, H. and {\c{C}}etinkaya-Rundel, M. and Grolemund, G.},
#   isbn={9781492097365},
#   url={https://books.google.com/books?id=TiLEEAAAQBAJ},
#   year={2023},
#   publisher={O'Reilly Media}
# }
#
# ## Slide 2
#
# ![Image Alt Text](/Users/yingminhe/Desktop/5000-lab-1.2/simple_quarto_website/slides/photo.png)
# ## Slide 3
#
# ![Image Alt Text](/Users/yingminhe/Desktop/5000-lab-1.2/simple_quarto_website/slides/my_image.jpeg)

# %% [markdown]
# ## Slide 4
#
# This slide includes a citation: [@wickham2023r]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)

plt.show()
